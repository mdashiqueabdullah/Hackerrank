# %%
teamp_records=[]
records=[]

def records_short_score(records):
    l=len(records)
    
    for i in range(0,l):
        for j in range(0,l-i-1):
            if records[j][1]>records[j+1][1]:
                temp=records[j]
                records[j]=records[j+1]
                records[j+1]=temp
    
                
                
def records_short_name(records):
    l=len(records)
    
    for i in range(0,l):
        for j in range(0,l-i-1):
            if records[j][0] > records[j+1][0]:
                temp=records[j]
                records[j]=records[j+1]
                records[j+1]=temp
            
    
def find_second_lowest(records):
    a=0
    i=0
    records_short_score(records)
    for x in range(len(records)):
        if records[x][1]>a:
            a= records[x][1]
            i=i+1
            if i==2:
                break
    return a
        

def final_oparation(records):
    i=0
    a=find_second_lowest(records)
    for x in range(len(records)):
        if records[x][1]==a:
            i=i+1
            
    if i==2:
        records_short_name(records)
        for x in range(len(records)):
            if records[x][1]==a:
                print(records[x][0])
    else:
        records_short_score(records)
        for x in range(len(records)):
            if records[x][1]==a:
                print(records[x][0])
            
        
    
        

for x in range(int(input())):
    
    name=input()
    score=float(input())
    if score < 0:
        score=score*(-1)
    teamp_records.append(name)
    teamp_records.append(score)
    records.append(teamp_records)
    teamp_records=[]
    


            
final_oparation(records)
    
    

# 4
# Sona
# -25.001
# Mona
# -25.0001
# Mini
# -25.000
# Rita
# -25.0
# Out:
# 4
# sona
# -25.001
# mona
# -25.0001
# mini
# -25.000
# rita
# -25.0
# mona
